# %%
import sqlite3
import os
import pandas as pd
import re
from bs4 import BeautifulSoup
import unicodedata
from pathlib import Path
from rapidfuzz import fuzz, process
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import pandas as pd
import time

# %%
! pip install rapidfuzz
! pip install geopy
# Out:
# Requirement already satisfied: rapidfuzz in /Users/gs/.pyenv/versions/3.13.2/lib/python3.13/site-packages (3.13.0)
# Requirement already satisfied: geopy in /Users/gs/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/gs/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from geopy) (2.0)

# %%
TEAM_CSV_PATH = './data/mapping/teams_map.csv'
LOGOS_BASE_PATH = './data/logos'
OUTPUT_CSV = './data/mapping/team_logo_mapping.csv'

# %%
import os
import shutil
from pathlib import Path

HISTORY_FOLDER = './data/history'
TARGET_FOLDER = './data/logos'

os.makedirs(TARGET_FOLDER, exist_ok=True)

for season_folder in Path(HISTORY_FOLDER).iterdir():
    if not season_folder.is_dir():
        continue

    for league_folder in season_folder.iterdir():
        if not league_folder.is_dir():
            continue

        # Extract "Country - League" from folder name
        country_league = league_folder.name.strip()

        for logo_file in league_folder.glob("*.png"):
            team_name = logo_file.stem.strip()
            new_filename = f"{team_name} - {country_league}.png"
            destination = Path(TARGET_FOLDER) / new_filename

            # Avoid overwriting if there's a duplicate
            if not destination.exists():
                shutil.copy2(logo_file, destination)

print(f"✅ Logos flattened into {TARGET_FOLDER}")
# Out:
# ✅ Logos flattened into ./data/logos

# %%
# Re-import required libraries since the environment was reset
import os
from pathlib import Path
import shutil
import unicodedata
import pandas as pd
from rapidfuzz import fuzz

# Paths
FLATTENED_FOLDER = "./data/logos"
DEDUPED_OUTPUT_FOLDER = "./data/logos_flat"

# Ensure output folder exists
os.makedirs(DEDUPED_OUTPUT_FOLDER, exist_ok=True)

# === Normalization + Deduplication Utilities ===

def normalize_team_name(name):
    """Cleans and standardizes a team name for fuzzy comparison."""
    name = unicodedata.normalize('NFKD', name).encode('ascii', 'ignore').decode('utf-8')
    name = name.lower()
    for word in ["fc", "sc", "ac", "cf", "afc", ".", ",", "-", "_"]:
        name = name.replace(word, "")
    return name.strip()

def deduplicate_logo_filenames(file_list, threshold=90):
    """
    Groups logo filenames (without extension) by fuzzy similarity.
    Returns a map: original_filename → canonical_name
    """
    canonical_map = {}
    used = set()

    for i, file in enumerate(file_list):
        if file in used:
            continue

        canon = file
        norm_canon = normalize_team_name(canon)
        canonical_map[file] = canon
        used.add(file)

        for other in file_list[i+1:]:
            if other in used:
                continue
            norm_other = normalize_team_name(other)
            score = fuzz.ratio(norm_canon, norm_other)

            if score >= threshold:
                canonical_map[other] = canon
                used.add(other)

    return canonical_map

# Get logo files and names
flattened_logo_files = [f for f in os.listdir(FLATTENED_FOLDER) if f.endswith('.png')]
flattened_logo_names = [Path(f).stem for f in flattened_logo_files]

# Apply deduplication
deduped_map = deduplicate_logo_filenames(flattened_logo_names, threshold=90)

# Write deduplicated logos into DEDUPED_OUTPUT_FOLDER
written = set()
for original_name, canonical_name in deduped_map.items():
    original_file = Path(FLATTENED_FOLDER) / f"{original_name}.png"
    output_file = Path(DEDUPED_OUTPUT_FOLDER) / f"{canonical_name}.png"

    if canonical_name not in written and original_file.exists():
        shutil.copy2(original_file, output_file)
        written.add(canonical_name)

# Return a summary
{
    "Original logos": len(flattened_logo_files),
    "Unique deduplicated logos": len(written),
    "Output folder": DEDUPED_OUTPUT_FOLDER
}
# Out:
# {'Original logos': 502,
#  'Unique deduplicated logos': 502,
#  'Output folder': './data/logos_flat'}

# %%
import os
from pathlib import Path
from rapidfuzz import process, fuzz

teams_map_df = pd.read_csv("./data/mapping/teams_map.csv")


# Load deduplicated logo filenames and parse team + metadata
deduped_folder = "./data/logos"
deduped_entries = []

if os.path.exists(deduped_folder):
    for f in os.listdir(deduped_folder):
        if f.endswith(".png"):
            parts = Path(f).stem.split(" - ")
            if len(parts) >= 3:
                deduped_entries.append({
                    "deduped_team": parts[0].strip(),
                    "country": parts[1].strip(),
                    "league": parts[2].strip(),
                    "logo_filename": f
                })

deduped_df = pd.DataFrame(deduped_entries)

# Match each team_long_name to the deduped logos
def normalize(name):
    if pd.isna(name):
        return ""
    return unicodedata.normalize('NFKD', name).encode('ascii', 'ignore').decode('utf-8').lower().replace("fc", "").replace("sc", "").replace("ac", "").replace("-", "").replace(",", "").strip()

results = []
for team in teams_map_df["team_long_name"].dropna().unique():
    best_match, score, _ = process.extractOne(
        normalize(team),
        deduped_df['deduped_team'].apply(normalize),
        scorer=fuzz.ratio
    )
    matched_row = deduped_df[deduped_df['deduped_team'].apply(normalize) == normalize(best_match)].iloc[0]
    results.append({
        "team_long_name": team,
        "matched_team": best_match,
        "match_score": score,
        "country": matched_row["country"],
        "league": matched_row["league"],
        "logo_filename": matched_row["logo_filename"]
    })

# Merge enriched results back into the original teams_map_df
enriched_df = pd.DataFrame(results)
final_teams_df = teams_map_df.merge(enriched_df, on="team_long_name", how="left")
final_teams_df.to_csv("./data/mapping/team_logo_mapping.csv", index=False)

# %%
# Load the uploaded team_logo_mapping.csv which should contain country information
geo_df = pd.read_csv("./data/mapping/team_logo_mapping.csv")


from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import unicodedata

# Prepare geolocator
geolocator = Nominatim(user_agent="team-geocoder", timeout=10)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# Function to clean team names for geocoding
def clean_team_name(name):
    if pd.isna(name):
        return ""
    name = unicodedata.normalize('NFKD', name).encode('ascii', 'ignore').decode('utf-8')
    words_to_remove = ['fc', 'sc', 'ac', 'cf', 'afc', 'sporting', 'club', 'rsc', 'krc', 'kaa', 'ksc', 'raec' , 'sv' , 'ksv', 'cercle', 'athletic' ]
    for word in words_to_remove:
        name = name.lower().replace(word, '')
    return name.strip().title()

# Clean the team name and build query again
geo_df["cleaned_query"] = geo_df.apply(lambda row: f"{clean_team_name(row['team_long_name'])}, {row['country']}", axis=1)

# Add empty columns for lat/lon
geo_df["latitude"] = None
geo_df["longitude"] = None

# Run geocoding
for i, row in geo_df.iterrows():
    try:
        location = geocode(row["cleaned_query"])
        if location:
            geo_df.at[i, "latitude"] = location.latitude
            geo_df.at[i, "longitude"] = location.longitude
            print(f"✓ {row['cleaned_query']} → {location.latitude}, {location.longitude}")
        else:
            print(f"⚠️ No result for {row['cleaned_query']}")
    except Exception as e:
        print(f"❌ Error geocoding {row['cleaned_query']}: {e}")

# Save results
output_path = "./data/mapping/team_logo_mapping_geocoded.csv"
geo_df.to_csv(output_path, index=False)
# Out:
# ✓ Genk, Belgium → 50.9654864, 5.5001456
# ⚠️ No result for Beerhot, Belgium
# ⚠️ No result for Sv Zulte-Waregem, Belgium
# ⚠️ No result for Lokeren, Portugal
# ⚠️ No result for Ksv Cercle Brugge, Belgium
# ✓ R Anderlecht, Belgium → 50.845386412012935, 4.340770380198071
# ✓ Gent, Belgium → 51.0538286, 3.7250121
# ✓ Mons, France → 43.6118557, 1.5721111
# ⚠️ No result for V Dender Eh, Belgium
# ✓ Standard De Liege, Belgium → 50.61095765, 5.54393415
# ✓ Kv Mechelen, Belgium → 51.0371829, 4.4863913
# ✓ Brugge Kv, Belgium → 51.2085526, 3.226772
# ✓ Ksv Roeselare, Belgium → 50.9520177, 3.1047304
# ✓ Kv Kortrijk, Belgium → 50.8276429, 3.2659884
# ⚠️ No result for Tubize, Portugal
# ⚠️ No result for Royal Excel Mouron, Belgium
# ✓ Kvc Westerlo, Belgium → 51.094091, 4.92812145796815
# ✓ Charleroi, Belgium → 50.4116233, 4.444528
# ⚠️ No result for Sint-Truidense Vv, Belgium
# ⚠️ No result for Lierse Sk, Norway
# ✓ Kas Eupen, Belgium → 50.6263653, 6.0453424
# ✓ Oud-Heverlee Leuven, Belgium → 50.8376275, 4.6629253
# ⚠️ No result for Waasland-Beveren, Czech Republic
# ✓ Kv Oostende, Belgium → 51.2258565, 2.919496
# ⚠️ No result for Royal Excel Mouron, Belgium
# ✓ Manchester United, England → 53.4649481, -2.2906349
# ✓ Newcastle United, England → 55.0041755, -1.5649326866735827
# ✓ Arsenal, England → 51.5583839, -0.1074866
# ✓ West Bromwich Albion, England → 52.56115045, -1.9507114384017314
# ⚠️ No result for Sunderland, Denmark
# ✓ Liverpool, England → 53.4071991, -2.99168
# ✓ West Ham United, England → 51.5697731, 0.460239
# ⚠️ No result for Wigan Athletic, Spain
# ✓ Aston Villa, England → 51.32041745, -2.5063290769304234
# ✓ Manchester City, England → 53.48309105, -2.2002520023433307
# ✓ Everton, England → 52.1462041, -0.2430129
# ⚠️ No result for Blkburn Rovers, Türkiye
# ⚠️ No result for Middlesbrough, Sweden
# ✓ Tottenham Hotspur, England → 51.604157, -0.0662604100000004
# ✓ Bolton Wanderers, England → 53.5794299, -2.515916282730622
# ✓ Stoke City, England → 53.006213, -2.1777553842365402
# ⚠️ No result for Hull City, Netherlands
# ✓ Fulham, England → 51.474408, -0.206809
# ✓ Chelsea, England → 51.4875167, -0.1687007
# ⚠️ No result for Portsmouth, Portugal
# ✓ Birmingham City, England → 52.4822706, -1.8888147987150585
# ✓ Wolverhampton Wanderers, England → 52.58927385, -2.1293414704232267
# ✓ Burnley, England → 53.7907262, -2.2439196
# ⚠️ No result for Blkpool, England
# ✓ Swansea City, England → 53.35696333976217, -2.9078394173368336
# ⚠️ No result for Queens Park Rangers, Czech Republic
# ✓ Norwich City, England → 52.6348426, 1.2871862
# ✓ Southampton, England → 50.9025349, -1.404189
# ✓ Reading, Belgium → 50.79410505, 5.351775734375002
# ⚠️ No result for Crystal Pale, England
# ⚠️ No result for Cardiff City, Netherlands
# ✓ Leicester City, England → 52.6232734, -1.1350487
# ✓ Bournemouth, England → 50.7201514, -1.8799118
# ✓ Watford, England → 51.6553875, -0.3957425
# ✓ Aj Auxerre, France → 47.7865182, 3.5873446
# ✓ Nantes, France → 47.2186371, -1.5541362
# ✓ Girondins De Bordeaux, France → 44.874122042924654, -0.6711750968323617
# ⚠️ No result for Sm Caen, Switzerland
# ✓ Le Havre, France → 49.4938975, 0.1079732
# ✓ Ogc Nice, France → 43.7041331, 7.1936019
# ✓ Le Mans, Poland → 51.142874, 16.9438726
# ✓ Lorient, France → 47.7477336, -3.3660907
# ✓ Olympique Lyonnais, France → 45.9878622, 4.7185309
# ✓ Toulouse, France → 43.6044622, 1.4442469
# ⚠️ No result for As Mono, France
# ✓ Paris Saint-Germain, France → 48.8715545, 2.3031549
# ✓ As Nancy-Lorraine, France → 48.6937223, 6.1834097
# ✓ Lo Lille, France → 50.6365654, 3.0635282
# ✓ Stade Rennais, France → 47.6359676, -2.95758165
# ✓ Olympique De Marseille, France → 43.3063963, 5.4609981
# ✓ Sochaux-Montbeliard, France → 47.5138641, 6.8305344
# ✓ Grenoble Foot 38, France → 45.1713763, 5.724695351878733
# ⚠️ No result for Valenciennes, Spain
# ✓ As Saint-Etienne, France → 44.409448749999996, 0.6947147630053399
# ⚠️ No result for Rc Lens, France
# ✓ Montpellier Herault, France → 43.6112422, 3.8767337
# ⚠️ No result for Us Boulogne Cote D'Opale, Belgium
# ⚠️ No result for Arles-Avignon, Scotland
# ✓ Stade Brestois 29, France → 48.4276292, -4.4699827
# ⚠️ No result for Ajcio, France
# ⚠️ No result for Evian Thonon Gaillard, England
# ⚠️ No result for Dijon O, Switzerland
# ✓ Stade De Reims, France → 49.2858867, 4.038407300941009
# ⚠️ No result for Bastia, Portugal
# ⚠️ No result for Es Troyes, France
# ⚠️ No result for En Avant De Guingamp, Spain
# ✓ Metz, France → 49.1196964, 6.1763552
# ✓ Angers O, France → 47.4739884, -0.5515588
# ⚠️ No result for G Ajcio, France
# ✓ Bayern Munich, Germany → 48.1768926, 11.5325626
# ⚠️ No result for Hamburger Sv, Scotland
# ✓ Bayer 04 Leverkusen, Germany → 51.015165709387816, 6.994099896740656
# ✓ Borussia Dortmund, Germany → 51.2817024, 8.858377
# ✓ Halke 04, Germany → 51.4787857, 6.2582643
# ✓ Hannover 96, France → 42.69405228715932, 2.8831919614466783
# ✓ Vfl Wolfsburg, Germany → 52.434490800000006, 10.806857351231887
# ✓ 1.  Koln, Germany → 51.0849669, 6.8476485
# ⚠️ No result for Eintrht Frankfurt, Germany
# ✓ Hertha B Berlin, Germany → 52.487676, 13.2786903
# ⚠️ No result for D Arminia Bielefeld, Germany
# ✓ Sv Werder Bremen, Germany → 53.0717335, 8.841534813937642
# ⚠️ No result for Energie Cottbus, Romania
# ✓ Tsg 1899 Hoffenheim, Germany → 49.27807285, 8.84247955656506
# ⚠️ No result for Borussia Monchengladbh, Germany
# ✓ Vfb Stuttgart, Germany → 48.7788452, 9.1783022
# ⚠️ No result for Karlsruher, Belgium
# ✓ Vfl Bochum, Germany → 51.5042713, 7.238554021441496
# ✓ Freiburg, Germany → 47.9960901, 7.8494005
# ✓ 1.  Nurnberg, Germany → 49.41744905, 11.117022511298138
# ✓ 1. Fsv Mainz 05, Germany → 50.00087035, 8.245562992298598
# ✓ 1.  Kaiserslautern, Germany → 49.46685555, 7.737999897829705
# ✓ St. Pauli, Germany → 53.5539347, 9.9594316
# ✓ Augsburg, Germany → 48.3690341, 10.8979522
# ⚠️ No result for Fortuna Dusseldorf, Netherlands
# ✓ Spvgg Greuther Furth, Germany → 49.50079805, 10.995901659139138
# ⚠️ No result for Eintrht Braunhweig, Germany
# ⚠️ No result for Paderborn 07, Hungary
# ⚠️ No result for Ingolstadt 04, Romania
# ⚠️ No result for Sv Darmstadt 98, Germany
# ✓ Atalanta, Italy → 43.08828715215496, 12.433227119673692
# ✓ Siena, England → 52.45665185, -1.8692997500000001
# ✓ Cagliari, Italy → 39.2171994, 9.113311
# ✓ Lazio, Italy → 41.9808038, 12.7662312
# ⚠️ No result for Catania, Portugal
# ✓ Genoa, Italy → 44.40726, 8.9338624
# ✓ Chievo Verona, Italy → 45.4575984, 10.9464024
# ⚠️ No result for Reggio Calabria, Belgium
# ✓ Fiorentina, Italy → 42.9637778, 10.5348607
# ✓ Juventus, Italy → 44.9779934, 7.6151806
# ✓ Milan, Italy → 45.4641943, 9.1896346
# ✓ Bologna, Italy → 44.4938203, 11.3426327
# ✓ Roma, Italy → 41.8933203, 12.4829321
# ✓ Napoli, Italy → 40.8358846, 14.2487679
# ✓ Sampdoria, Italy → 44.4155493, 8.952667661712866
# ✓ Inter, Switzerland → 46.2271379, 6.1217816
# ✓ Torino, Italy → 45.0677551, 7.6824892
# ✓ Lecce, Italy → 40.152217300000004, 18.2260628338229
# ✓ Udinese, Italy → 45.9434149, 13.3406411
# ✓ Palermo, Belgium → 51.210047, 4.3950193
# ✓ Bari, Germany → 51.2588285, 6.3855174
# ✓ Livorno, England → 53.8071862, -1.4494259
# ✓ Parma, Serbia → 44.8666563, 20.346283
# ⚠️ No result for Cesena, England
# ⚠️ No result for Breia, Netherlands
# ⚠️ No result for Novara, Croatia
# ⚠️ No result for Peara, Serbia
# ✓ Hellas Verona, Italy → 45.4334792, 10.8928406
# ✓ Sassuolo, Italy → 44.5409769, 10.7829023
# ✓ Empoli, Italy → 43.7194884, 10.9458556
# ✓ Frosinone, Italy → 41.628546799999995, 13.57584977062367
# ✓ Carpi, Portugal → 41.8458995, -8.4188328
# ✓ Vitesse, Netherlands → 52.00993, 5.8175382
# ✓ Groningen, Netherlands → 53.2190652, 6.5680077
# ⚠️ No result for Roda Jc Kerkrade, Serbia
# ✓ Twente, Netherlands → 52.3066217, 6.687373934148023
# ✓ Willem Ii, Netherlands → 51.54269165, 5.066806624191194
# ✓ Ajax, Netherlands → 52.3446377, 4.9502708
# ✓ N.E.C., Türkiye → 18.105483, -15.982913
# ⚠️ No result for De Graafhap, Spain
# ✓ Utrecht, Netherlands → 52.0907006, 5.1215634
# ⚠️ No result for Psv, Hungary
# ⚠️ No result for Herles Almelo, Netherlands
# ✓ Feyenoord, Netherlands → 51.241244, 5.9681522
# ✓ Sparta Rotterdam, Netherlands → 51.9194555, 4.433550650698857
# ⚠️ No result for Ado Den Haag, Denmark
# ✓ Volendam, Netherlands → 52.4963759, 5.0682736
# ✓ Heerenveen, Netherlands → 52.998474200000004, 5.923148795038062
# ✓ Az, Italy → 45.1827919, 9.1541648
# ✓ N Breda, Netherlands → 51.5887845, 4.7760237
# ✓ Rkc Waalwijk, Netherlands → 51.6885312, 5.0881794
# ⚠️ No result for Vvv-Venlo, Portugal
# ✓ Excelsior, Netherlands → 51.37123067044777, 6.153883830856253
# ✓ Pec Zwolle, Netherlands → 52.517052, 6.1198816
# ✓ Cambuur, Netherlands → 53.204109387252714, 5.81144821817786
# ⚠️ No result for Go Ahead Eagles, Netherlands
# ✓ Dordrecht, Belgium → 51.204946621071315, 4.459860735000204
# ⚠️ No result for Wisa Krakow, Poland
# ⚠️ No result for Polonia Bytom, Ukraine
# ⚠️ No result for Polonia Bytom, Ukraine
# ✓ Ruch Chorzow, Poland → 50.30109535, 18.97563265
# ✓ Legia Warszawa, Poland → 52.220641099999995, 21.039798345752295
# ✓ P. Warszawa, Poland → 52.2565288, 20.93857286507725
# ⚠️ No result for Slask Wrocaw, Poland
# ✓ Lechia Gdansk, Poland → 54.3689105, 18.6254975
# ⚠️ No result for Widzew Odz, Poland
# ⚠️ No result for Odra Wodzisaw, Austria
# ✓ Lech Poznan, Poland → 52.718690300000006, 16.373662178218478
# ⚠️ No result for Gks Bechatow, Poland
# ⚠️ No result for Arka Gdynia, Portugal
# ⚠️ No result for Jagiellonia Biaystok, Poland
# ✓ Piast Gliwice, Poland → 50.2888459, 18.689488122169813
# ⚠️ No result for Crovia, Poland
# ✓ Korona Kielce, Poland → 50.8818631, 20.6146634
# ⚠️ No result for Zagebie Lubin, Poland
# ⚠️ No result for Widzew Odz, Poland
# ⚠️ No result for Podbeskidzie Bielsko-Biaa, Denmark
# ✓ Pogon Szczecin, Poland → 53.4328063, 14.5114468
# ✓ Zawisza Bydgoszcz, Poland → 53.145594200000005, 18.020850655712383
# ⚠️ No result for Gornik Eczna, Poland
# ✓ Termalica Bruk-Bet Nieciecza, Poland → 50.159814600000004, 20.850376997712942
# ✓ Porto, Portugal → 41.1494512, -8.6107884
# ✓ Os Belenenses, Portugal → 39.7276869, -8.929905816368382
# ✓ Cp, Portugal → 38.5308951, -8.8851227
# ✓ Trofense, Portugal → 41.3356932, -8.5606961
# ✓ Vitoria Guimaraes, Portugal → 41.4428381, -8.292789550000002
# ⚠️ No result for Vitoria Setubal, Czech Republic
# ✓ Pos De Ferreira, Portugal → 41.1746603, -8.597003921087204
# ✓ Braga, Portugal → 41.5510583, -8.4280045
# ✓ Amadora, Italy → 43.8306926, 7.8496335
# ⚠️ No result for Ademica De Coimbra, Poland
# ✓ Rio Ave, Portugal → 41.4420431, -8.369404
# ✓ Sl Benfica, Portugal → 38.7524036, -9.183121411941231
# ⚠️ No result for Leixoes, Greece
# ⚠️ No result for Cd Nional, Portugal
# ⚠️ No result for Naval 1 De Maio, Spain
# ⚠️ No result for Cs Maritimo, Portugal
# ⚠️ No result for Uniao De Leiria, Sad, Spain
# ⚠️ No result for S.C. Olhanense, Scotland
# ✓ Portimonense, Portugal → 37.1366247, -8.540189
# ✓ Beira Mar, Spain → 43.707218100000006, -7.691239855329776
# ✓ Feirense, Portugal → 40.9271044, -8.5466116
# ✓ Gil Vicente, Portugal → 38.7518035, -9.152244
# ✓ Moreirense, Portugal → 41.378031699999994, -8.354995054507953
# ✓ Estoril Praia, Portugal → 38.6932572, -9.368928726120114
# ✓ Arouca, Portugal → 40.9289214, -8.2441746
# ⚠️ No result for Penafiel, Denmark
# ✓ Boavista, Portugal → 41.157648, -8.6374973
# ⚠️ No result for Uniao Da Madeira, Hungary
# ✓ Tondela, Portugal → 40.51642, -8.08053
# ⚠️ No result for Falkirk, Hungary
# ✓ Rangers, Scotland → 55.9331349, -4.304716243431738
# ✓ Heart Of Midlothian, Scotland → 55.9495655, -3.1914772
# ✓ Motherwell, Scotland → 55.7893512, -3.9904173
# ✓ Kilmarnock, Scotland → 55.6100589, -4.4964652
# ✓ Hibernian, Scotland → 55.9209854, -2.9269098264180213
# ✓ Aberdeen, Scotland → 57.1482429, -2.0928095
# ⚠️ No result for Inverness Caledonian Thistle, Ukraine
# ✓ Celtic, Scotland → 55.85018145, -4.2068226877121955
# ✓ St. Mirren, Scotland → 55.850534350000004, -4.444205372848037
# ⚠️ No result for Hamilton Ademical, Spain
# ✓ Dundee United, Scotland → 56.473158, -2.9680270551715076
# ✓ St. Johnstone, Scotland → 56.1519963152431, -3.8041406519906227
# ⚠️ No result for Dunfermline Athletic, Spain
# ✓ Dundee, Scotland → 56.4605938, -2.97019
# ✓ Ross County, Scotland → 57.595873850000004, -4.419063880031938
# ⚠️ No result for Partick Thistle F.C., Serbia
# ✓ Valencia, Spain → 39.4697065, -0.3763353
# ✓ Rcd Mallorca, Spain → 39.5698469, 2.6494492
# ✓ Ca Osasuna, Spain → 42.79667355, -1.637125547008285
# ✓ Villarreal, Spain → 39.9372616, -0.1004465
# ⚠️ No result for Rc Deportivo De La Coruna, Spain
# ✓ Real Madrid, Spain → 40.4199798, -3.7035925
# ✓ Cd Numancia, Spain → 40.3995283, -3.6596765
# ✓ Barcelona, Spain → 41.3828939, 2.1774322
# ⚠️ No result for Ring Santander, Denmark
# ✓ Sevilla, Spain → 37.3886303, -5.9953403
# ⚠️ No result for Real  De Gijon, Portugal
# ✓ Getafe, Spain → 40.3070639, -3.7331808
# ✓ Real Betis Balompie, Spain → 37.308368349999995, -5.948074387220609
# ⚠️ No result for Rc Recreativo, Belgium
# ✓ Rcd Espanyol, Spain → 41.4260382, 2.2119056
# ✓ Real Valladolid, Spain → 41.6508549, -4.7125553
# ✓ Athletic  De Bilbao, Spain → 40.0690114, -2.138824
# ✓ Ud Almeria, Spain → 36.8414197, -2.4628135
# ✓ Atletico Madrid, Spain → 40.37562969613464, -3.742049156756476
# ✓ Malaga, Spain → 36.7213028, -4.4216366
# ✓ Xerez  Deportivo, Spain → 36.68845801939576, -6.12159618332931
# ✓ Real Zaragoza, Spain → 41.6557975, -0.8795481
# ⚠️ No result for Cd Tenerife, Portugal
# ⚠️ No result for Hercules  De Futbol, Netherlands
# ✓ Levante Ud, Spain → 39.4703751, -0.370525
# ✓ Real Sociedad, Spain → 43.307890400000005, -1.9742816856871923
# ✓ Granada, Spain → 37.1734995, -3.5995337
# ✓ Rayo Vallecano, Spain → 40.377091050000004, -3.6140329350855245
# ✓ Rc Celta De Vigo, Spain → 42.2123817, -8.7401108
# ✓ Elche, Spain → 38.2653307, -0.6988391
# ⚠️ No result for Sd Eibar, Portugal
# ✓ Cordoba, Spain → 37.8845813, -4.7760138
# ✓ Ud Las Palmas, Spain → 28.00225515, -15.4057081
# ✓ Grasshopper  Zurich, Switzerland → 47.3564463, 8.536044
# ✓ Bellinzona, Spain → 40.517374513386414, -4.25852085562589
# ⚠️ No result for B Young Boys, Switzerland
# ✓ Basel, Switzerland → 47.5581077, 7.5878261
# ⚠️ No result for Aarau, Romania
# ✓ Sion, Switzerland → 46.2311749, 7.3588795
# ✓ Luzern, Switzerland → 47.0505452, 8.3054682
# ✓ Vaduz, Spain → 36.40916525, -6.1525787
# ⚠️ No result for Neuchatel Xamax, Portugal
# ✓ Zurich, Switzerland → 47.3744489, 8.5410422
# ✓ St. Gallen, Switzerland → 47.425618, 9.3762397
# ⚠️ No result for Thun, Belgium
# ✓ Servette, Switzerland → 46.2134636, 6.130226900852341
# ✓ Lausanne-Sports, Switzerland → 46.5342787, 6.625131155979333
# ✓ Lugano, Italy → 46.0200392, 9.2369985
